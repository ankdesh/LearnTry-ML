# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/home/ankdesh/explore/LearnTry-ML/RL/spinningup/spinup/algos/pytorch/vpg/vpg/vpg_s0/progress.txt',delimiter='\t')

# %%
print (df.columns)
# Out:
# Index(['Epoch', 'AverageEpRet', 'StdEpRet', 'MaxEpRet', 'MinEpRet', 'EpLen',
#        'AverageVVals', 'StdVVals', 'MaxVVals', 'MinVVals', 'TotalEnvInteracts',
#        'LossPi', 'LossV', 'DeltaLossPi', 'DeltaLossV', 'Entropy', 'KL',
#        'Time'],
#       dtype='object')

# %%
print (df.head())
# Out:
#    Epoch  AverageEpRet   StdEpRet  MaxEpRet  MinEpRet      EpLen  \
# 0      0     20.381443   9.572774      70.0       9.0  20.381443
# 1      1     21.763737  11.290091      82.0      10.0  21.763737
# 2      2     21.543957  11.582752      84.0       9.0  21.543957
# 3      3     24.668750  13.052645      74.0       9.0  24.668750
# 4      4     22.556818  11.945766      63.0       9.0  22.556818
#
#    AverageVVals  StdVVals   MaxVVals  MinVVals  TotalEnvInteracts    LossPi  \
# 0     -0.256991  0.068807  -0.048631 -0.437677               4000  0.005884
# 1      7.753438  0.281185   8.096844  6.087248               8000  0.006263
# 2     11.341524  2.816449  13.109364 -6.593933              12000  0.005252
# 3     12.816299  3.421899  14.919990 -4.624176              16000  0.002910
# 4     14.085104  4.480398  16.897388 -5.229043              20000  0.000334
#
#        LossV  DeltaLossPi  DeltaLossV   Entropy            KL      Time
# ...

# %%
df[["AverageEpRet","Entropy","Epoch"]].plot.line(x="Epoch", subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Epoch'>, <AxesSubplot:xlabel='Epoch'>],
#       dtype=object)
