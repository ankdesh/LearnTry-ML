# %%
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
import gym

from huggingface_sb3 import load_from_hub, package_to_hub, push_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env

# %%
import gym

# First, we create our environment called LunarLander-v2
env = gym.make("LunarLander-v2")

# Then we reset this environment
observation = env.reset()

for _ in range(20):
  # Take a random action
  action = env.action_space.sample()
  print("Action taken:", action)

  # Do this action in the environment and get
  # next_state, reward, done and info
  observation, reward, done, info = env.step(action)
  
  # If the game is done (in our case we land, crashed or timeout)
  if done:
      # Reset the environment
      print("Environment is reset")
      observation = env.reset()
# Out:
# Action taken: 0
# Action taken: 2
# Action taken: 1
# Action taken: 2
# Action taken: 0
# Action taken: 2
# Action taken: 2
# Action taken: 3
# Action taken: 3
# Action taken: 0
# Action taken: 1
# Action taken: 0
# Action taken: 1
# Action taken: 3
# Action taken: 0
# Action taken: 1
# Action taken: 3
# Action taken: 1
# Action taken: 3
# Action taken: 0

# %%
# We create our environment with gym.make("<name_of_the_environment>")
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [ 1.0956166   0.08822614 -0.27322415 -0.9062121   1.4270515  -0.6515286
#   0.03129386  0.44468513]

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 2

# %%
# Create the environment
env = make_vec_env('LunarLander-v2', n_envs=16)

# %%
model = PPO(
            policy = "MlpPolicy",
            env=env,
            n_steps=1024,
            batch_size=64,
            n_epochs=4,
            gamma=0.999,
            gae_lambda=0.98,
            ent_coef=0.01,
            verbose=1)
# Out:
# Using cuda device

# %%
# Train it for 1,000,000 timesteps
model.learn(total_timesteps=1000000)
# Save the model
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.3     |
# |    ep_rew_mean     | -188     |
# | time/              |          |
# |    fps             | 3267     |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.2        |
# |    ep_rew_mean          | -154        |
# | time/                   |             |
# |    fps                  | 2423        |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009077182 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.0013     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.6e+03     |
# |    n_updates            | 4           |
# |    policy_gradient_loss | -0.00489    |
# |    value_loss           | 4.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.4        |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 2314        |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006298544 |
# |    clip_fraction        | 0.0383      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.000382   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 814         |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00443    |
# |    value_loss           | 2.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.7        |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 2282        |
# |    iterations           | 4           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009743091 |
# |    clip_fraction        | 0.0504      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.00106    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 414         |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 1.3e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97.1         |
# |    ep_rew_mean          | -101         |
# | time/                   |              |
# |    fps                  | 2231         |
# |    iterations           | 5            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0092470255 |
# |    clip_fraction        | 0.0823       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.000687    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 175          |
# |    n_updates            | 16           |
# |    policy_gradient_loss | -0.00477     |
# |    value_loss           | 620          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 112         |
# |    ep_rew_mean          | -86.3       |
# | time/                   |             |
# |    fps                  | 2133        |
# |    iterations           | 6           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.007018772 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.00027     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 269         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0063     |
# |    value_loss           | 582         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | -74         |
# | time/                   |             |
# |    fps                  | 2065        |
# |    iterations           | 7           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.009080669 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.0621     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 236         |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.00642    |
# |    value_loss           | 372         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 114         |
# |    ep_rew_mean          | -66.9       |
# | time/                   |             |
# |    fps                  | 2033        |
# |    iterations           | 8           |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.009309253 |
# |    clip_fraction        | 0.0913      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.00738     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 216         |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.00478    |
# |    value_loss           | 409         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 125         |
# |    ep_rew_mean          | -45.5       |
# | time/                   |             |
# |    fps                  | 2037        |
# |    iterations           | 9           |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.011127906 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -0.00978    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 206         |
# |    n_updates            | 32          |
# |    policy_gradient_loss | -0.00734    |
# |    value_loss           | 412         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | -39.8       |
# | time/                   |             |
# |    fps                  | 2002        |
# |    iterations           | 10          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.009203831 |
# |    clip_fraction        | 0.0624      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -0.00131    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 167         |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00381    |
# |    value_loss           | 418         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 208          |
# |    ep_rew_mean          | -26.3        |
# | time/                   |              |
# |    fps                  | 1897         |
# |    iterations           | 11           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0084845815 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | -0.00131     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 278          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 591          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 179         |
# |    ep_rew_mean          | -41         |
# | time/                   |             |
# |    fps                  | 1849        |
# |    iterations           | 12          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.005811578 |
# |    clip_fraction        | 0.0544      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.000316    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 263         |
# |    n_updates            | 44          |
# |    policy_gradient_loss | -0.00318    |
# |    value_loss           | 444         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 254         |
# |    ep_rew_mean          | -27.2       |
# | time/                   |             |
# |    fps                  | 1718        |
# |    iterations           | 13          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.004372758 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 8.31e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 351         |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 916         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 335          |
# |    ep_rew_mean          | -8.65        |
# | time/                   |              |
# |    fps                  | 1652         |
# |    iterations           | 14           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0022921269 |
# |    clip_fraction        | 0.00153      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.00661      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 166          |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00053     |
# |    value_loss           | 369          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 376        |
# |    ep_rew_mean          | -5.53      |
# | time/                   |            |
# |    fps                  | 1562       |
# |    iterations           | 15         |
# |    time_elapsed         | 157        |
# |    total_timesteps      | 245760     |
# | train/                  |            |
# |    approx_kl            | 0.00431999 |
# |    clip_fraction        | 0.0166     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.19      |
# |    explained_variance   | 0.32       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 174        |
# |    n_updates            | 56         |
# |    policy_gradient_loss | -0.00135   |
# |    value_loss           | 425        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 444          |
# |    ep_rew_mean          | 8.03         |
# | time/                   |              |
# |    fps                  | 1486         |
# |    iterations           | 16           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0048375996 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.562        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 101          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 210          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 457          |
# |    ep_rew_mean          | 13           |
# | time/                   |              |
# |    fps                  | 1457         |
# |    iterations           | 17           |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0046044346 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.69         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.7         |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.000804    |
# |    value_loss           | 155          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 11.2         |
# | time/                   |              |
# |    fps                  | 1429         |
# |    iterations           | 18           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0062290886 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.747        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 54.4         |
# |    n_updates            | 68           |
# |    policy_gradient_loss | -0.00282     |
# |    value_loss           | 207          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 450          |
# |    ep_rew_mean          | 14.6         |
# | time/                   |              |
# |    fps                  | 1395         |
# |    iterations           | 19           |
# |    time_elapsed         | 223          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0058811842 |
# |    clip_fraction        | 0.0264       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.806        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87.2         |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00252     |
# |    value_loss           | 179          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 492          |
# |    ep_rew_mean          | 27.7         |
# | time/                   |              |
# |    fps                  | 1359         |
# |    iterations           | 20           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0072916383 |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.839        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 61.8         |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.00309     |
# |    value_loss           | 143          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 538          |
# |    ep_rew_mean          | 39.3         |
# | time/                   |              |
# |    fps                  | 1337         |
# |    iterations           | 21           |
# |    time_elapsed         | 257          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0042040916 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.876        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.6         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000901    |
# |    value_loss           | 99.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 604          |
# |    ep_rew_mean          | 53.9         |
# | time/                   |              |
# |    fps                  | 1313         |
# |    iterations           | 22           |
# |    time_elapsed         | 274          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0061619794 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.883        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.5         |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 109          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 663          |
# |    ep_rew_mean          | 67.4         |
# | time/                   |              |
# |    fps                  | 1293         |
# |    iterations           | 23           |
# |    time_elapsed         | 291          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0035318062 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.891        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.6         |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 92.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 710          |
# |    ep_rew_mean          | 73.6         |
# | time/                   |              |
# |    fps                  | 1272         |
# |    iterations           | 24           |
# |    time_elapsed         | 308          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0076918737 |
# |    clip_fraction        | 0.078        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.915        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.1         |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.00305     |
# |    value_loss           | 86           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 749          |
# |    ep_rew_mean          | 86.4         |
# | time/                   |              |
# |    fps                  | 1253         |
# |    iterations           | 25           |
# |    time_elapsed         | 326          |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0054058977 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17           |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 54           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 836         |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 1234        |
# |    iterations           | 26          |
# |    time_elapsed         | 345         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.009382414 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.62        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00301    |
# |    value_loss           | 37.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 830          |
# |    ep_rew_mean          | 99.3         |
# | time/                   |              |
# |    fps                  | 1221         |
# |    iterations           | 27           |
# |    time_elapsed         | 362          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0058606714 |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.9          |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.000585    |
# |    value_loss           | 33.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 839          |
# |    ep_rew_mean          | 97.2         |
# | time/                   |              |
# |    fps                  | 1205         |
# |    iterations           | 28           |
# |    time_elapsed         | 380          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0046508107 |
# |    clip_fraction        | 0.0326       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.93         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.7         |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 88.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 867         |
# |    ep_rew_mean          | 97.7        |
# | time/                   |             |
# |    fps                  | 1193        |
# |    iterations           | 29          |
# |    time_elapsed         | 397         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.004957573 |
# |    clip_fraction        | 0.0424      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.1        |
# |    n_updates            | 112         |
# |    policy_gradient_loss | -0.00147    |
# |    value_loss           | 63.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 883         |
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 1181        |
# |    iterations           | 30          |
# |    time_elapsed         | 415         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.003891066 |
# |    clip_fraction        | 0.0348      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.04        |
# |    n_updates            | 116         |
# |    policy_gradient_loss | -0.00153    |
# |    value_loss           | 43.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 851          |
# |    ep_rew_mean          | 91           |
# | time/                   |              |
# |    fps                  | 1166         |
# |    iterations           | 31           |
# |    time_elapsed         | 435          |
# |    total_timesteps      | 507904       |
# | train/                  |              |
# |    approx_kl            | 0.0046630716 |
# |    clip_fraction        | 0.0346       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.7         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00165     |
# |    value_loss           | 25.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 868          |
# |    ep_rew_mean          | 91.5         |
# | time/                   |              |
# |    fps                  | 1152         |
# |    iterations           | 32           |
# |    time_elapsed         | 454          |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0059800153 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.936        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.2         |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 59           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | 95.9        |
# | time/                   |             |
# |    fps                  | 1141        |
# |    iterations           | 33          |
# |    time_elapsed         | 473         |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.006041874 |
# |    clip_fraction        | 0.0614      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.4        |
# |    n_updates            | 128         |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 78.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 922          |
# |    ep_rew_mean          | 101          |
# | time/                   |              |
# |    fps                  | 1134         |
# |    iterations           | 34           |
# |    time_elapsed         | 491          |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0047857724 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3            |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.000895    |
# |    value_loss           | 25.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 917          |
# |    ep_rew_mean          | 104          |
# | time/                   |              |
# |    fps                  | 1125         |
# |    iterations           | 35           |
# |    time_elapsed         | 509          |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0056648958 |
# |    clip_fraction        | 0.0574       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.37         |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.00186     |
# |    value_loss           | 14.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 931          |
# |    ep_rew_mean          | 110          |
# | time/                   |              |
# |    fps                  | 1121         |
# |    iterations           | 36           |
# |    time_elapsed         | 526          |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0059448206 |
# |    clip_fraction        | 0.0425       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.67         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000234    |
# |    value_loss           | 11.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 940         |
# |    ep_rew_mean          | 117         |
# | time/                   |             |
# |    fps                  | 1116        |
# |    iterations           | 37          |
# |    time_elapsed         | 542         |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.008288735 |
# |    clip_fraction        | 0.0329      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.5        |
# |    n_updates            | 144         |
# |    policy_gradient_loss | -0.00133    |
# |    value_loss           | 24.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 948          |
# |    ep_rew_mean          | 124          |
# | time/                   |              |
# |    fps                  | 1113         |
# |    iterations           | 38           |
# |    time_elapsed         | 559          |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0024447741 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.993       |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 71.7         |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 58.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 926          |
# |    ep_rew_mean          | 127          |
# | time/                   |              |
# |    fps                  | 1111         |
# |    iterations           | 39           |
# |    time_elapsed         | 575          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0045167357 |
# |    clip_fraction        | 0.0415       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.999       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.98         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.000545    |
# |    value_loss           | 17.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 926         |
# |    ep_rew_mean          | 130         |
# | time/                   |             |
# |    fps                  | 1104        |
# |    iterations           | 40          |
# |    time_elapsed         | 593         |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.003308675 |
# |    clip_fraction        | 0.014       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.15        |
# |    n_updates            | 156         |
# |    policy_gradient_loss | 0.00025     |
# |    value_loss           | 33.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 926          |
# |    ep_rew_mean          | 131          |
# | time/                   |              |
# |    fps                  | 1100         |
# |    iterations           | 41           |
# |    time_elapsed         | 610          |
# |    total_timesteps      | 671744       |
# | train/                  |              |
# |    approx_kl            | 0.0044086524 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.98        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.000208     |
# |    value_loss           | 15.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 940         |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 1094        |
# |    iterations           | 42          |
# |    time_elapsed         | 628         |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.005697005 |
# |    clip_fraction        | 0.0433      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.59        |
# |    n_updates            | 164         |
# |    policy_gradient_loss | -0.00225    |
# |    value_loss           | 4.65        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 963          |
# |    ep_rew_mean          | 141          |
# | time/                   |              |
# |    fps                  | 1090         |
# |    iterations           | 43           |
# |    time_elapsed         | 645          |
# |    total_timesteps      | 704512       |
# | train/                  |              |
# |    approx_kl            | 0.0038833339 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.949       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02         |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.000153    |
# |    value_loss           | 4.17         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 963         |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 1088        |
# |    iterations           | 44          |
# |    time_elapsed         | 662         |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.003431551 |
# |    clip_fraction        | 0.0272      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.937      |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.81        |
# |    n_updates            | 172         |
# |    policy_gradient_loss | -0.00117    |
# |    value_loss           | 27          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 985         |
# |    ep_rew_mean          | 146         |
# | time/                   |             |
# |    fps                  | 1085        |
# |    iterations           | 45          |
# |    time_elapsed         | 679         |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.003936652 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2           |
# |    n_updates            | 176         |
# |    policy_gradient_loss | -0.000315   |
# |    value_loss           | 3.95        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 984         |
# |    ep_rew_mean          | 147         |
# | time/                   |             |
# |    fps                  | 1083        |
# |    iterations           | 46          |
# |    time_elapsed         | 695         |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.003252483 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.967      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.875       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.000521   |
# |    value_loss           | 3.18        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 968          |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 1081         |
# |    iterations           | 47           |
# |    time_elapsed         | 712          |
# |    total_timesteps      | 770048       |
# | train/                  |              |
# |    approx_kl            | 0.0038352755 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.958       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.37         |
# |    n_updates            | 184          |
# |    policy_gradient_loss | 0.000257     |
# |    value_loss           | 14.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 147          |
# | time/                   |              |
# |    fps                  | 1078         |
# |    iterations           | 48           |
# |    time_elapsed         | 728          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0033370263 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.934       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.35         |
# |    n_updates            | 188          |
# |    policy_gradient_loss | 0.000273     |
# |    value_loss           | 13.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 150          |
# | time/                   |              |
# |    fps                  | 1077         |
# |    iterations           | 49           |
# |    time_elapsed         | 744          |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0069257845 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.873       |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.49         |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 14.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 929          |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 1077         |
# |    iterations           | 50           |
# |    time_elapsed         | 760          |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 0.0035889638 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.898       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.814        |
# |    n_updates            | 196          |
# |    policy_gradient_loss | 1.09e-05     |
# |    value_loss           | 35.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 928         |
# |    ep_rew_mean          | 146         |
# | time/                   |             |
# |    fps                  | 1077        |
# |    iterations           | 51          |
# |    time_elapsed         | 775         |
# |    total_timesteps      | 835584      |
# | train/                  |             |
# |    approx_kl            | 0.004552711 |
# |    clip_fraction        | 0.0155      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.885      |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.54        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00108    |
# |    value_loss           | 46.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 926         |
# |    ep_rew_mean          | 147         |
# | time/                   |             |
# |    fps                  | 1076        |
# |    iterations           | 52          |
# |    time_elapsed         | 791         |
# |    total_timesteps      | 851968      |
# | train/                  |             |
# |    approx_kl            | 0.004136088 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.866      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.3        |
# |    n_updates            | 204         |
# |    policy_gradient_loss | -0.00116    |
# |    value_loss           | 26.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 934          |
# |    ep_rew_mean          | 149          |
# | time/                   |              |
# |    fps                  | 1075         |
# |    iterations           | 53           |
# |    time_elapsed         | 807          |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0046946397 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.839       |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.61         |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.00106     |
# |    value_loss           | 46           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 942          |
# |    ep_rew_mean          | 147          |
# | time/                   |              |
# |    fps                  | 1075         |
# |    iterations           | 54           |
# |    time_elapsed         | 822          |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0034940627 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.834       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.3         |
# |    n_updates            | 212          |
# |    policy_gradient_loss | 0.000174     |
# |    value_loss           | 11.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 950         |
# |    ep_rew_mean          | 146         |
# | time/                   |             |
# |    fps                  | 1074        |
# |    iterations           | 55          |
# |    time_elapsed         | 838         |
# |    total_timesteps      | 901120      |
# | train/                  |             |
# |    approx_kl            | 0.005825683 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.826      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15        |
# |    n_updates            | 216         |
# |    policy_gradient_loss | -0.000466   |
# |    value_loss           | 2.04        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 955          |
# |    ep_rew_mean          | 156          |
# | time/                   |              |
# |    fps                  | 1073         |
# |    iterations           | 56           |
# |    time_elapsed         | 855          |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0047748312 |
# |    clip_fraction        | 0.0499       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.84        |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.298        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00228     |
# |    value_loss           | 1.7          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 948         |
# |    ep_rew_mean          | 158         |
# | time/                   |             |
# |    fps                  | 1071        |
# |    iterations           | 57          |
# |    time_elapsed         | 871         |
# |    total_timesteps      | 933888      |
# | train/                  |             |
# |    approx_kl            | 0.004298684 |
# |    clip_fraction        | 0.026       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.782      |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 95          |
# |    n_updates            | 224         |
# |    policy_gradient_loss | -0.000588   |
# |    value_loss           | 105         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 954         |
# |    ep_rew_mean          | 163         |
# | time/                   |             |
# |    fps                  | 1071        |
# |    iterations           | 58          |
# |    time_elapsed         | 886         |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.004934761 |
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.757      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.814       |
# |    n_updates            | 228         |
# |    policy_gradient_loss | -0.0012     |
# |    value_loss           | 43.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 918          |
# |    ep_rew_mean          | 173          |
# | time/                   |              |
# |    fps                  | 1072         |
# |    iterations           | 59           |
# |    time_elapsed         | 901          |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0034815567 |
# |    clip_fraction        | 0.0238       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.756       |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.6         |
# |    n_updates            | 232          |
# |    policy_gradient_loss | -0.000293    |
# |    value_loss           | 60.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 869          |
# |    ep_rew_mean          | 189          |
# | time/                   |              |
# |    fps                  | 1072         |
# |    iterations           | 60           |
# |    time_elapsed         | 916          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0070810164 |
# |    clip_fraction        | 0.075        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.708       |
# |    explained_variance   | 0.909        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.6         |
# |    n_updates            | 236          |
# |    policy_gradient_loss | -0.0033      |
# |    value_loss           | 181          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 799          |
# |    ep_rew_mean          | 206          |
# | time/                   |              |
# |    fps                  | 1075         |
# |    iterations           | 61           |
# |    time_elapsed         | 929          |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0035351098 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.66        |
# |    explained_variance   | 0.904        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.8         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 182          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 626         |
# |    ep_rew_mean          | 230         |
# | time/                   |             |
# |    fps                  | 1078        |
# |    iterations           | 62          |
# |    time_elapsed         | 942         |
# |    total_timesteps      | 1015808     |
# | train/                  |             |
# |    approx_kl            | 0.005263026 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.659      |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 257         |
# |    n_updates            | 244         |
# |    policy_gradient_loss | -0.00295    |
# |    value_loss           | 282         |
# -----------------------------------------

# %%
#@title
eval_env = gym.make("LunarLander-v2")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /home/ankdesh/virtualenvs/stable-baselines3-host/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward=255.69 +/- 20.244327934762797

# %%
notebook_login()
# !git config --global credential.helper store
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /home/ankdesh/.huggingface/token
# Login successful

# %%
import gym

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

# PLACE the variables you've just defined two cells above
# Define the name of the environment
env_id = "LunarLander-v2"

# TODO: Define the model architecture we used
model_architecture = "PPO"

## Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
## CHANGE WITH YOUR REPO ID
repo_id = "ankdesh/ppo-LunarLander-v2" # Change with your repo id, you can't push with mine 😄

## Define the commit message
commit_message = "Upload PPO LunarLander-v2 trained agent"

# Create the evaluation env
eval_env = DummyVecEnv([lambda: gym.make(env_id)])

# PLACE the package_to_hub function you've just filled here
package_to_hub(model=model, # Our trained model
               model_name=model_name, # The name of our trained model 
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message=commit_message)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /home/ankdesh/virtualenvs/stable-baselines3-host/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Saving video to /tmp/tmp0y4nbezv/-step-0-to-step-1000.mp4
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/tmp0y4nbezv/-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:20.02, start: 0.000000, bitrate: 103 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 600x400, 98 kb/s, 50 fps, 50 tbr, 12800 tbn, 100 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5572767373c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5572767373c0] profile High, level 3.1
# [libx264 @ 0x5572767373c0] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/tmp/tmpqt10e1tq/replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 600x400, q=-1--1, 50 fps, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame= 1001 fps=952 q=-1.0 Lsize=     242kB time=00:00:19.96 bitrate=  99.3kbits/s speed=  19x
# video:230kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.403152%
# [libx264 @ 0x5572767373c0] frame I:5     Avg QP:13.06  size:  2163
# [libx264 @ 0x5572767373c0] frame P:259   Avg QP:22.89  size:   303
# [libx264 @ 0x5572767373c0] frame B:737   Avg QP:25.66  size:   197
# [libx264 @ 0x5572767373c0] consecutive B-frames:  0.7%  1.6%  5.4% 92.3%
# [libx264 @ 0x5572767373c0] mb I  I16..4: 74.0% 19.6%  6.4%
# [libx264 @ 0x5572767373c0] mb P  I16..4:  0.2%  0.5%  0.4%  P16..4:  1.8%  0.5%  0.2%  0.0%  0.0%    skip:96.3%
# [libx264 @ 0x5572767373c0] mb B  I16..4:  0.1%  0.1%  0.3%  B16..8:  3.2%  0.4%  0.1%  direct: 0.1%  skip:95.8%  L0:55.3% L1:43.6% BI: 1.1%
# [libx264 @ 0x5572767373c0] 8x8 transform intra:25.5% inter:11.5%
# [libx264 @ 0x5572767373c0] coded y,uvDC,uvAC intra: 13.5% 25.2% 24.1% inter: 0.2% 0.3% 0.2%
# [libx264 @ 0x5572767373c0] i16 v,h,dc,p: 80% 14%  5%  0%
# [libx264 @ 0x5572767373c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 13% 62%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x5572767373c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 11% 62%  2%  3%  2%  2%  2%  2%
# [libx264 @ 0x5572767373c0] i8c dc,h,v,p: 89%  7%  5%  0%
# [libx264 @ 0x5572767373c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5572767373c0] ref P L0: 58.0%  1.8% 26.0% 14.2%
# [libx264 @ 0x5572767373c0] ref B L0: 66.1% 29.6%  4.3%
# [libx264 @ 0x5572767373c0] ref B L1: 91.1%  8.9%
# [libx264 @ 0x5572767373c0] kb/s:93.68
# ℹ Pushing repo ankdesh/ppo-LunarLander-v2 to the Hugging Face Hub
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/ankdesh/ppo-LunarLander-v2/tree/main/
# 'https://huggingface.co/ankdesh/ppo-LunarLander-v2/tree/main/'

# %%
from huggingface_sb3 import load_from_hub
repo_id = "Classroom-workshop/assignment2-omar" # The repo_id
filename = "ppo-LunarLander-v2.zip" # The model filename.zip

# When the model was trained on Python 3.8 the pickle protocol is 5
# But Python 3.6, 3.7 use protocol 4
# In order to get compatibility we need to:
# 1. Install pickle5 (we done it at the beginning of the colab)
# 2. Create a custom empty object we pass as parameter to PPO.load()
custom_objects = {
            "learning_rate": 0.0,
            "lr_schedule": lambda _: 0.0,
            "clip_range": lambda _: 0.0,
}

checkpoint = load_from_hub(repo_id, filename)
model = PPO.load(checkpoint, custom_objects=custom_objects, print_system_info=True)
# Out:
# Downloading:   0%|          | 0.00/146k [00:00<?, ?B/s]
# == CURRENT SYSTEM INFO ==
# OS: Linux-5.4.0-135-generic-x86_64-with-glibc2.29 #152-Ubuntu SMP Wed Nov 23 20:19:22 UTC 2022
# Python: 3.8.10
# Stable-Baselines3: 1.6.2
# PyTorch: 1.13.0+cu117
# GPU Enabled: True
# Numpy: 1.23.5
# Gym: 0.21.0
#
# == SAVED MODEL SYSTEM INFO ==
# OS: Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic #1 SMP Sun Apr 24 10:03:06 PDT 2022
# Python: 3.7.13
# Stable-Baselines3: 1.5.0
# PyTorch: 1.11.0+cu113
# GPU Enabled: True
# Numpy: 1.21.6
# Gym: 0.21.0

# %%
#@title
eval_env = gym.make("LunarLander-v2")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /home/ankdesh/virtualenvs/stable-baselines3-host/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward=302.82 +/- 19.110658853012456
