# %%
import tabula

# %%
# Read pdf into list of DataFrame
dfs = tabula.read_pdf("~/temp/test.pdf", pages='all')
# Out:
# Got stderr: Jul 15, 2024 8:01:14 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Jul 15, 2024 8:01:14 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Jul 15, 2024 8:01:14 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 36 fonts
# Jul 15, 2024 8:01:14 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Times-Roman
# Jul 15, 2024 8:01:14 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Times-Bold
# Jul 15, 2024 8:01:14 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Times-Italic
# Jul 15, 2024 8:01:14 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# ...

# %%
print (dfs)
# Out:
# [       Unnamed: 0                                Evaluation  \
# 0             NaN                      Large Language Model
# 1               •                      G eneral Performance
# 2               •                         Sp ecific Domains
# 3               •                    R e trieval Capability
# 4             NaN     ChunkingFine-tuneQuery Classification
# 5             NaN                                       NaN
# 6               •                                  D isturb
# 7               •                                   R andom
# 8               •                      N o  r mal Retrieval
# 9             NaN                         • O riginal Query
# 10  Summarization                                   • BM 25
# 11            NaN                             • C ontriever
# 12              •               Ex tractive • LL M-Embedder
# 13            NaN              • R ecomp • Q uery Rewriting
# 14            NaN            • BM 25 • Q uery Decomposition
# ...

# %%
# convert PDF into CSV file
tabula.convert_into("~/temp/test.pdf", "output.csv", output_format="csv", pages='all')
# Out:
# Got stderr: Jul 15, 2024 8:02:24 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Times-Roman
# Jul 15, 2024 8:02:24 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Times-Bold
# Jul 15, 2024 8:02:24 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Times-Italic
# Jul 15, 2024 8:02:24 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Times-BoldItalic
# Jul 15, 2024 8:02:24 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Helvetica
# Jul 15, 2024 8:02:24 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Helvetica-Bold
# Jul 15, 2024 8:02:24 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# ...

# %%
# !pwd
# Out:
# /home/ankdesh/explore/LearnTry-ML/llm/misc
