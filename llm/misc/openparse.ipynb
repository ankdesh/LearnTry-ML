# %%
import openparse

# %%
basic_doc_path = "/home/ankdesh/temp/test.pdf"
parser = openparse.DocumentParser()
parsed_basic_doc = parser.parse(basic_doc_path)

# %%
types = set()
for node in parsed_basic_doc.nodes:
    for element in node.elements:
        types.add(element.variant.name)

# %%
element.json()
# Out:
# '{"text":"For all datasets, we use greedy decoding during generation. To better compare the capabilities of \\ndifferent RAG modules, we adopt the 0-shot evaluation setting, i.e., no in-context examples are \\noffered. In the multiple choice and fact checking tasks, answers generated by the model may take \\na variety of forms (e.g., “the answer is A” instead of “A”). Therefore, we preprocess the responses \\ngenerated by the model, applying regular expression templates to match them with gold labels. ","lines":[{"bbox":[108.0,496.25,504.0,506.22],"spans":[{"text":"For all datasets, we use greedy decoding during generation. To better compare the capabilities of ","is_bold":false,"is_italic":false,"size":9.96}],"style":null,"text":"For all datasets, we use greedy decoding during generation. To better compare the capabilities of "},{"bbox":[108.0,485.35,504.0,495.31],"spans":[{"text":"different RAG modules, we adopt the 0-shot evaluation setting, i.e., no in-context examples are ","is_bold":false,"is_italic":false,"size":9.96}],"style":null,"text":"different RAG modules, we adopt the 0-shot evaluation setting, i.e., no in-context examples are "},{"bbox":[108.0,474.44,504.0,484.4],"spans":[{"text":"offered. In the multiple choice and fact checking tasks, answers generated by the model may take ","is_bold":false,"is_italic":false,"size":9.96}],"style":null,"text":"offered. In the multiple choice and fact checking tasks, answers generated by the model may take "},{"bbox":[108.0,463.53,504.0,473.49],"spans":[{"text":"a variety of forms (e.g., “the answer is A” instead of “A”). Therefore, we preprocess the responses ","is_bold":false,"is_italic":false,"size":9.96}],"style":null,"text":"a variety of forms (e.g., “the answer is A” instead of “A”). Therefore, we preprocess the responses "},{"bbox":[108.0,452.62,485.4,462.58],"spans":[{"text":"generated by the model, applying regular expression templates to match them with gold labels. ","is_bold":false,"is_italic":false,"size":9.96}],"style":null,"text":"generated by the model, applying regular expression templates to match them with gold labels. "}],"bbox":{"page":21,"page_height":792.0,"page_width":612.0,"x0":108.0,"y0":452.62,"x1":504.0,"y1":506.22},"variant":"text","embed_text":"For all datasets, we use greedy decoding during generation. To better compare the capabilities of \\ndifferent RAG modules, we adopt the 0-shot evaluation setting, i.e., no in-context examples are \\noffered. In the multiple choice and fact checking tasks, answers generated by the model may take \\na variety of forms (e.g., “the answer is A” instead of “A”). Therefore, we preprocess the responses \\ngenerated by the model, applying regular expression templates to match them with gold labels. "}'

# %%
from pprint import pprint
pprint (node.elements[0].variant.value)
# Out:
# 'text'

# %%
parser = openparse.DocumentParser(
        table_args={
            "parsing_algorithm": "unitable",
            "min_table_confidence": 0.8,
        },
)
parsed_nodes = parser.parse(basic_doc_path)
# Out:
# config.json:   0%|          | 0.00/76.5k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/76.8k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# Finished loading models. Ready for inference.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 7
#       1 parser = openparse.DocumentParser(
#       2         table_args={
#       3             "parsing_algorithm": "unitable",
#       4             "min_table_confidence": 0.8,
#       5         },
#       6 )
# ----> 7 parsed_nodes = parser.parse(basic_doc_path)
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/openparse/doc_parser.py:105, in DocumentParser.parse(self, file, ocr)
#     103 if self.table_args:
#     104     table_args_obj = _table_args_dict_to_model(self.table_args)
# --> 105     table_elems = tables.ingest(doc, table_args_obj, verbose=self._verbose)
#     106     table_nodes = self._elems_to_nodes(table_elems)
#     108 nodes = text_nodes + table_nodes
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/openparse/tables/parse.py:229, in ingest(doc, parsing_args, verbose)
#     227     return _ingest_with_pymupdf(doc, parsing_args, verbose)
#     228 elif isinstance(parsing_args, UnitableArgs):
# --> 229     return _ingest_with_unitable(doc, parsing_args, verbose)
#     230 else:
#     231     raise ValueError("Unsupported parsing_algorithm.")
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/openparse/tables/parse.py:195, in _ingest_with_unitable(doc, args, verbose)
#     187 padded_bbox = adjust_bbox_with_padding(
#     188     bbox=table_bbox.bbox,
#     189     page_width=page.rect.width,
#     190     page_height=page.rect.height,
#     191     padding_pct=padding_pct,
#     192 )
#     193 table_img = crop_img_with_padding(pdf_as_imgs[page_num], padded_bbox)
# --> 195 table_str = table_img_to_html(table_img)
#     197 # Flip y-coordinates to match the top-left origin system
#     198 fy0 = page.rect.height - padded_bbox[3]
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/openparse/tables/unitable/core.py:195, in table_img_to_html(table_image)
#     193 pred_html = predict_html(image_tensor)
#     194 pred_bbox = predict_bboxes(image_tensor, image_size=table_image.size)
# --> 195 pred_cell_lst = predict_cells(image_tensor, pred_bbox, table_image)
#     197 table_str_lst = build_table_from_html_and_cell(pred_html, pred_cell_lst)
#     198 table_str = "".join(table_str_lst)
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/openparse/tables/unitable/core.py:168, in predict_cells(image_tensor, pred_bboxes, image)
#     165 image_tensor_batch = torch.cat(image_tensor_lst, dim=0)
#     167 # Inference
# --> 168 pred_cell = _autoregressive_decode(
#     169     model=cell_model,
#     170     image=image_tensor_batch,
#     171     prefix=[cell_vocab.token_to_id("[cell]")],
#     172     max_decode_len=200,
#     173     eos_id=cell_vocab.token_to_id("<eos>"),
#     174     token_whitelist=None,
#     175     token_blacklist=[cell_vocab.token_to_id(i) for i in INVALID_CELL_TOKEN],
#     176 )
#     178 # Convert token id to token text
#     179 pred_cell = pred_cell.detach().cpu().numpy()
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/openparse/tables/unitable/core.py:99, in _autoregressive_decode(model, image, prefix, max_decode_len, eos_id, token_whitelist, token_blacklist)
#      97 with torch.no_grad():
#      98     causal_mask = subsequent_mask(context.shape[1]).to(device)
# ---> 99     logits = model.decode(
#     100         memory, context, tgt_mask=causal_mask, tgt_padding_mask=None  # type: ignore
#     101     )
#     102     logits = model.generator(logits)[:, -1, :]
#     104 logits = pred_token_within_range(
#     105     logits.detach(),
#     106     white_list=token_whitelist,
#     107     black_list=token_blacklist,
#     108 )
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/openparse/tables/unitable/tabular_transformer.py:199, in EncoderDecoder.decode(self, memory, tgt, tgt_mask, tgt_padding_mask)
#     195 def decode(
#     196     self, memory: Tensor, tgt: Tensor, tgt_mask: Tensor, tgt_padding_mask: Tensor
#     197 ) -> Tensor:
#     198     tgt_feature = self.pos_embed(self.token_embed(tgt))
# --> 199     tgt = self.decoder(tgt_feature, memory, tgt_mask, tgt_padding_mask)
#     201     return tgt
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/openparse/tables/unitable/tabular_transformer.py:111, in Decoder.forward(self, x, memory, tgt_mask, tgt_padding_mask)
#     108 def forward(
#     109     self, x: Tensor, memory: Tensor, tgt_mask: Tensor, tgt_padding_mask: Tensor
#     110 ) -> Tensor:
# --> 111     x = self.decoder(
#     112         x, memory, tgt_mask=tgt_mask, tgt_key_padding_mask=tgt_padding_mask
#     113     )
#     114     return x
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/torch/nn/modules/transformer.py:494, in TransformerDecoder.forward(self, tgt, memory, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask, tgt_is_causal, memory_is_causal)
#     491 tgt_is_causal = _detect_is_causal_mask(tgt_mask, tgt_is_causal, seq_len)
#     493 for mod in self.layers:
# --> 494     output = mod(output, memory, tgt_mask=tgt_mask,
#     495                  memory_mask=memory_mask,
#     496                  tgt_key_padding_mask=tgt_key_padding_mask,
#     497                  memory_key_padding_mask=memory_key_padding_mask,
#     498                  tgt_is_causal=tgt_is_causal,
#     499                  memory_is_causal=memory_is_causal)
#     501 if self.norm is not None:
#     502     output = self.norm(output)
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/torch/nn/modules/transformer.py:886, in TransformerDecoderLayer.forward(self, tgt, memory, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask, tgt_is_causal, memory_is_causal)
#     884 x = tgt
#     885 if self.norm_first:
# --> 886     x = x + self._sa_block(self.norm1(x), tgt_mask, tgt_key_padding_mask, tgt_is_causal)
#     887     x = x + self._mha_block(self.norm2(x), memory, memory_mask, memory_key_padding_mask, memory_is_causal)
#     888     x = x + self._ff_block(self.norm3(x))
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/torch/nn/modules/transformer.py:899, in TransformerDecoderLayer._sa_block(self, x, attn_mask, key_padding_mask, is_causal)
#     897 def _sa_block(self, x: Tensor,
#     898               attn_mask: Optional[Tensor], key_padding_mask: Optional[Tensor], is_causal: bool = False) -> Tensor:
# --> 899     x = self.self_attn(x, x, x,
#     900                        attn_mask=attn_mask,
#     901                        key_padding_mask=key_padding_mask,
#     902                        is_causal=is_causal,
#     903                        need_weights=False)[0]
#     904     return self.dropout1(x)
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/explore/LearnTry-ML/llm/.venv/lib/python3.10/site-packages/torch/nn/modules/activation.py:1221, in MultiheadAttention.forward(self, query, key, value, key_padding_mask, need_weights, attn_mask, average_attn_weights, is_causal)
#    1218         merged_mask, mask_type = self.merge_masks(attn_mask, key_padding_mask, query)
#    1220         if self.in_proj_bias is not None and self.in_proj_weight is not None:
# -> 1221             return torch._native_multi_head_attention(
#    1222                 query,
#    1223                 key,
#    1224                 value,
#    1225                 self.embed_dim,
#    1226                 self.num_heads,
#    1227                 self.in_proj_weight,
#    1228                 self.in_proj_bias,
#    1229                 self.out_proj.weight,
#    1230                 self.out_proj.bias,
#    1231                 merged_mask,
#    1232                 need_weights,
#    1233                 average_attn_weights,
#    1234                 mask_type)
#    1236 any_nested = query.is_nested or key.is_nested or value.is_nested
#    1237 assert not any_nested, ("MultiheadAttention does not support NestedTensor outside of its fast path. " +
#    1238                         f"The fast path was not hit because {why_not_fast_path}")
#
# KeyboardInterrupt:
