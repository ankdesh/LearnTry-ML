# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
print (words[:20])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'as', 'originated', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.088327
# Nearest to known: ballarat, karabiners, disputed, thinker, channels, resupply, torturing, pusan,
# Nearest to after: wang, waterway, billie, debugger, masse, marca, expect, items,
# Nearest to can: blazing, vent, hackman, tub, swann, bodywork, eldridge, rhinoceros,
# Nearest to used: muscat, fairy, territories, eerie, giotto, peas, levees, spacecraft,
# Nearest to will: coding, nguema, av, uzi, cuban, larva, unstated, dreaded,
# Nearest to he: coincide, chuppah, considering, sanitarium, klimt, kuhn, agave, donaldson,
# Nearest to two: danforth, tarsus, catenary, marlene, cheated, mcgill, mononoke, kentucky,
# Nearest to state: mazes, voltaic, euskal, leaks, hsbc, expos, stream, mennonites,
# Nearest to into: bertolt, xie, cheerful, learn, plumes, connie, nfl, fletcher,
# Nearest to i: relevance, monolith, branwell, nicolae, sore, wrongful, resigns, discourages,
# Nearest to this: breuer, weapons, vigor, witold, ssr, kickstart, emitter, novelty,
# Nearest to their: kmaq, postgresql, depressing, balanced, contraband, pickard, hass, malfunction,
# Nearest to three: death, exhibits, reneged, bumper, solve, lycopene, devour, haymarket,
# Nearest to all: tragedy, herzog, quay, lot, jj, aries, boucher, ultraviolet,
# Nearest to not: ditch, careers, cliches, utensils, assyrians, arleigh, distinguishes, angevin,
# Nearest to on: cries, ashley, redshifts, editable, complexity, murad, dougherty, foix,
# Average loss at step 2000: 4.363000
# Average loss at step 4000: 3.872195
# Average loss at step 6000: 3.786704
# Average loss at step 8000: 3.688162
# Average loss at step 10000: 3.612309
# Nearest to known: resupply, marketed, ballarat, colloquially, torturing, karabiners, millennial, well,
# Nearest to after: before, nfl, marca, rature, during, moh, repel, buyer,
# Nearest to can: would, may, will, must, should, hackman, blazing, hogs,
# Nearest to used: colouring, fairy, forcible, damietta, consilience, fianna, emerald, known,
# Nearest to will: might, can, coding, could, nguema, would, av, uzi,
# Nearest to he: it, they, she, there, who, somebody, we, christensen,
# Nearest to two: three, five, four, six, eight, seven, one, zero,
# Nearest to state: doubleheader, leaks, rodr, holidays, mennonites, magnetic, voltaic, fabricius,
# Nearest to into: from, nfl, connectedness, xie, in, ibanez, frankish, oahu,
# Nearest to i: keats, cosmology, impedance, branwell, sampling, arroyo, maoism, decoder,
# Nearest to this: it, the, which, any, no, that, weapons, a,
# Nearest to their: its, his, kmaq, kerguelen, the, candu, depressing, this,
# Nearest to three: four, five, eight, six, two, seven, zero, nine,
# Nearest to all: arouse, initiative, herzog, bites, sterreich, most, directrix, areas,
# Nearest to not: they, cure, it, to, auditorium, your, bound, acquis,
# Nearest to on: in, within, domestic, at, llywelyn, klerk, corvus, lavinia,
# Average loss at step 12000: 3.602308
# Average loss at step 14000: 3.571496
# Average loss at step 16000: 3.410221
# Average loss at step 18000: 3.465533
# Average loss at step 20000: 3.541587
# Nearest to known: such, used, well, marketed, seen, colloquially, resupply, torturing,
# Nearest to after: before, during, nfl, repel, amadeus, at, acceptors, monolith,
# Nearest to can: would, may, will, must, should, could, cannot, johann,
# Nearest to used: known, found, darshan, colouring, seen, fairy, sewers, damietta,
# Nearest to will: would, might, can, could, may, to, nguema, coding,
# Nearest to he: it, she, they, who, there, which, this, christensen,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to state: doubleheader, rodr, blackmail, newline, troops, amir, melt, generals,
# Nearest to into: from, nfl, breakdance, xie, stately, tentacles, across, frankish,
# Nearest to i: impedance, they, iii, arroyo, coppa, maoism, civilisation, ii,
# Nearest to this: it, which, any, that, the, he, no, its,
# Nearest to their: its, his, the, her, kmaq, neill, some, this,
# Nearest to three: four, five, two, six, seven, eight, zero, nine,
# Nearest to all: these, many, sterreich, areas, arouse, herzog, directrix, tipped,
# Nearest to not: it, they, never, usually, to, still, cure, also,
# Nearest to on: within, in, at, domestic, copyrighted, corvus, tilbury, job,
# Average loss at step 22000: 3.499034
# Average loss at step 24000: 3.489096
# Average loss at step 26000: 3.481534
# Average loss at step 28000: 3.480759
# Average loss at step 30000: 3.504731
# Nearest to known: used, well, such, marketed, seen, referred, regarded, infractions,
# Nearest to after: before, during, when, repel, nfl, for, until, at,
# Nearest to can: may, would, could, will, must, should, cannot, to,
# Nearest to used: known, seen, found, referred, written, involved, colouring, isin,
# Nearest to will: would, can, could, may, might, must, should, to,
# Nearest to he: she, it, they, who, there, christensen, somebody, we,
# Nearest to two: four, three, five, one, six, seven, eight, zero,
# Nearest to state: doubleheader, rodr, blackmail, newline, bagpipes, argentines, amir, crystals,
# Nearest to into: from, through, across, breakdance, during, nfl, on, magnificence,
# Nearest to i: ii, we, you, impedance, iii, immunoglobulins, keats, they,
# Nearest to this: which, it, that, any, there, thermodynamics, no, the,
# Nearest to their: its, his, the, her, these, many, some, your,
# Nearest to three: four, five, seven, six, two, eight, zero, nine,
# Nearest to all: these, some, many, areas, quantitatively, sterreich, mitford, bodyguards,
# Nearest to not: they, it, still, never, to, regency, there, geddes,
# Nearest to on: within, in, through, upon, domestic, lavinia, keflav, under,
# Average loss at step 32000: 3.500913
# Average loss at step 34000: 3.491373
# Average loss at step 36000: 3.455557
# Average loss at step 38000: 3.296752
# Average loss at step 40000: 3.428919
# Nearest to known: used, such, marketed, well, seen, defined, served, regarded,
# Nearest to after: before, during, when, through, while, bosch, until, amadeus,
# Nearest to can: may, could, will, would, must, should, cannot, shall,
# Nearest to used: seen, known, found, referred, involved, considered, written, designed,
# Nearest to will: would, can, could, may, must, might, should, cannot,
# Nearest to he: she, it, they, who, there, we, i, christensen,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to state: doubleheader, newline, rodr, crystals, bagpipes, northumbrian, argentines, amir,
# Nearest to into: through, from, across, breakdance, xie, nfl, whereabouts, poisonous,
# Nearest to i: we, you, they, ii, he, coppa, sharkey, opined,
# Nearest to this: which, it, the, that, any, khomeini, thermodynamics, another,
# Nearest to their: its, his, her, the, your, these, guidebook, some,
# Nearest to three: four, five, six, two, seven, eight, zero, nine,
# Nearest to all: both, these, quantitatively, sterreich, every, areas, nyasaland, many,
# Nearest to not: still, it, they, never, usually, there, often, geddes,
# Nearest to on: upon, at, during, near, onto, against, ledge, in,
# Average loss at step 42000: 3.437551
# Average loss at step 44000: 3.454180
# Average loss at step 46000: 3.451073
# Average loss at step 48000: 3.353740
# Average loss at step 50000: 3.390537
# Nearest to known: used, marketed, such, regarded, well, referred, defined, seen,
# Nearest to after: before, during, when, while, through, until, amadeus, since,
# Nearest to can: could, would, may, will, must, should, cannot, might,
# Nearest to used: known, seen, referred, found, written, designed, involved, attempting,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to he: she, it, they, who, there, we, superman, but,
# Nearest to two: three, four, seven, one, six, five, eight, zero,
# Nearest to state: doubleheader, rodr, amir, crystals, scrutiny, northumbrian, sabotage, newline,
# Nearest to into: through, from, across, evoking, between, around, quell, ibanez,
# Nearest to i: we, you, ii, sharkey, coppa, they, watt, g,
# Nearest to this: which, it, tc, the, some, that, there, he,
# Nearest to their: its, his, her, your, the, both, vending, some,
# Nearest to three: four, seven, six, eight, five, two, nine, zero,
# Nearest to all: both, every, these, each, many, melodramatic, sterreich, quantitatively,
# Nearest to not: never, still, usually, strongly, they, who, now, always,
# Nearest to on: in, upon, through, within, near, onto, reinstatement, detecting,
# Average loss at step 52000: 3.438488
# Average loss at step 54000: 3.425904
# Average loss at step 56000: 3.441012
# Average loss at step 58000: 3.397486
# Average loss at step 60000: 3.391231
# Nearest to known: used, such, regarded, well, marketed, seen, defined, referred,
# Nearest to after: before, during, when, through, while, until, since, although,
# Nearest to can: could, may, would, will, must, cannot, should, might,
# Nearest to used: known, referred, seen, found, designed, written, involved, available,
# Nearest to will: would, could, may, can, might, must, should, cannot,
# Nearest to he: she, it, they, who, there, we, never, previously,
# Nearest to two: three, four, five, six, one, eight, seven, zero,
# Nearest to state: doubleheader, crystals, scrutiny, sco, rodr, bagpipes, paternity, delineate,
# Nearest to into: through, from, across, in, around, magnificence, between, quell,
# Nearest to i: we, ii, you, coppa, they, he, clemency, watt,
# Nearest to this: which, it, that, the, there, some, itself, tc,
# Nearest to their: its, his, her, the, your, our, some, these,
# Nearest to three: five, four, eight, six, two, seven, nine, zero,
# Nearest to all: both, every, these, many, those, some, each, any,
# Nearest to not: still, never, usually, you, they, always, now, to,
# Nearest to on: upon, through, onto, within, in, about, withered, near,
# Average loss at step 62000: 3.240966
# Average loss at step 64000: 3.261298
# Average loss at step 66000: 3.404349
# Average loss at step 68000: 3.390831
# Average loss at step 70000: 3.358053
# Nearest to known: used, regarded, such, defined, seen, marketed, referred, described,
# Nearest to after: before, during, when, until, while, through, amadeus, kicked,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to used: known, seen, referred, designed, found, available, written, involved,
# Nearest to will: would, could, may, can, might, must, should, cannot,
# Nearest to he: she, it, they, there, who, we, eventually, golf,
# Nearest to two: three, one, six, four, seven, five, eight, zero,
# Nearest to state: doubleheader, states, scrutiny, government, bagpipes, crystals, sco, knapp,
# Nearest to into: through, from, across, breakdance, magnificence, monotone, within, beyond,
# Nearest to i: we, ii, you, coppa, watt, sharkey, g, they,
# Nearest to this: it, which, the, there, another, that, some, tc,
# Nearest to their: its, his, her, the, your, our, these, pliocene,
# Nearest to three: four, two, six, five, seven, eight, nine, zero,
# Nearest to all: many, some, both, any, every, these, most, each,
# Nearest to not: never, still, now, always, usually, generally, popularly, geddes,
# Nearest to on: through, upon, within, in, under, improves, ledge, about,
# Average loss at step 72000: 3.375880
# Average loss at step 74000: 3.342113
# Average loss at step 76000: 3.323630
# Average loss at step 78000: 3.350301
# Average loss at step 80000: 3.378512
# Nearest to known: used, regarded, defined, such, referred, seen, viewed, described,
# Nearest to after: before, during, when, while, through, despite, amadeus, until,
# Nearest to can: could, may, would, will, must, should, might, cannot,
# Nearest to used: known, seen, referred, available, written, designed, found, regarded,
# Nearest to will: would, could, can, may, might, must, should, did,
# Nearest to he: she, it, they, there, who, we, but, eventually,
# Nearest to two: three, four, six, one, seven, five, eight, zero,
# Nearest to state: government, states, doubleheader, apostolic, delicate, scrutiny, federal, shikai,
# Nearest to into: through, across, from, within, beyond, around, down, breakdance,
# Nearest to i: ii, we, you, g, watt, sharkey, bju, soci,
# Nearest to this: it, which, itself, tc, there, some, another, the,
# Nearest to their: its, his, her, your, our, both, any, my,
# Nearest to three: four, six, five, seven, two, eight, nine, zero,
# Nearest to all: both, any, every, some, many, each, several, charitable,
# Nearest to not: still, never, usually, actually, always, generally, deemed, it,
# Nearest to on: upon, through, in, within, manipulative, ledge, onto, under,
# Average loss at step 82000: 3.409372
# Average loss at step 84000: 3.409829
# Average loss at step 86000: 3.390127
# Average loss at step 88000: 3.356745
# Average loss at step 90000: 3.368715
# Nearest to known: used, regarded, such, seen, defined, described, referred, viewed,
# Nearest to after: before, during, when, until, while, through, if, amadeus,
# Nearest to can: may, could, will, must, would, should, cannot, might,
# Nearest to used: known, seen, referred, available, designed, found, considered, called,
# Nearest to will: would, could, can, may, must, might, should, cannot,
# Nearest to he: she, it, they, there, who, but, later, woodson,
# Nearest to two: three, four, seven, five, eight, six, one, nine,
# Nearest to state: city, federal, sco, doubleheader, rodr, government, view, apostolic,
# Nearest to into: through, from, across, within, around, down, evoking, kanagawa,
# Nearest to i: you, we, ii, watt, g, coppa, sharkey, t,
# Nearest to this: it, which, the, some, itself, another, antennae, any,
# Nearest to their: its, his, her, your, our, vending, my, guidebook,
# Nearest to three: five, two, four, seven, eight, six, nine, zero,
# Nearest to all: many, some, both, every, several, charitable, these, any,
# Nearest to not: still, never, popularly, deemed, usually, nor, concentrating, nevertheless,
# Nearest to on: upon, through, onto, under, around, within, in, against,
# Average loss at step 92000: 3.395980
# Average loss at step 94000: 3.251074
# Average loss at step 96000: 3.356411
# Average loss at step 98000: 3.237012
# Average loss at step 100000: 3.361961
# Nearest to known: used, regarded, such, defined, described, referred, seen, viewed,
# Nearest to after: before, during, when, although, despite, while, until, amadeus,
# Nearest to can: may, could, must, will, would, should, might, cannot,
# Nearest to used: referred, seen, found, known, designed, available, considered, written,
# Nearest to will: would, could, can, must, may, might, should, cannot,
# Nearest to he: she, it, they, who, there, we, this, never,
# Nearest to two: four, three, five, six, seven, eight, one, zero,
# Nearest to state: doubleheader, rodr, sco, amir, city, whaling, oxford, generals,
# Nearest to into: through, within, across, from, onto, in, breakdance, towards,
# Nearest to i: you, we, ii, watt, lieutenant, they, he, t,
# Nearest to this: it, which, another, itself, prohibiting, he, some, the,
# Nearest to their: its, his, her, your, our, the, vending, whose,
# Nearest to three: two, six, five, four, eight, seven, nine, zero,
# Nearest to all: many, every, any, these, some, several, various, both,
# Nearest to not: never, still, popularly, you, deemed, t, nor, legally,
# Nearest to on: upon, through, onto, in, within, at, against, near,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
